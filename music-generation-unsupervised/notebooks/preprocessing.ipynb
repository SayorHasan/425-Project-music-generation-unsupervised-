# %% [markdown]
# # Preprocessing
#
# This notebook is a placeholder to match the required project layout.
# Implement piano-roll window creation and/or tokenization here, or use the scripts under `src/preprocessing/`.
